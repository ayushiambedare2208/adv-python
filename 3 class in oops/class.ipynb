# %% [markdown]
# # CLASS IN OBJECT ORIENTED PROGRAMMING

# %%
a = 23
print(type(a))
# Out:
# <class 'int'>

# %%
b = -45
print(type(b))
# Out:
# <class 'int'>

# %%
c = 24.59
print(type(c))
# Out:
# <class 'float'>

# %%
d = [1, 2, 3, 4, 5]
print(type(d))
# Out:
# <class 'list'>

# %% [markdown]
# DATAFRAME ATTRIBUTES AND METHODS

# %%
data = {
    "Roll_no.": [101, 102, 103],
    "Names": ["Ayushi", "Pranay", "Janvi"],
    "Marks": [78.27, 87, 90],
    "Hobbies": ["Reading", "Singing", "Dancing"]
}
print(type(data))
# Out:
# <class 'dict'>

# %%
import pandas as pd
df = pd.DataFrame(data)
df
# Out:
#    Roll_no.   Names  Marks  Hobbies
# 0       101  Ayushi  78.27  Reading
# 1       102  Pranay  87.00  Singing
# 2       103   Janvi  90.00  Dancing

# %%
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# DATAFRAME ATTRIBUTES
# 1. df.columns
# 2. df.index
# 3. df.values
# 4. df.shape
# 5. df.dtypes
# 6. df.size

# %%
df.columns
# Out:
# Index(['Roll_no.', 'Names', 'Marks', 'Hobbies'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
df.values
# Out:
# array([[101, 'Ayushi', 78.27, 'Reading'],
#        [102, 'Pranay', 87.0, 'Singing'],
#        [103, 'Janvi', 90.0, 'Dancing']], dtype=object)

# %%
df.shape
# Out:
# (3, 4)

# %%
df.dtypes
# Out:
# Roll_no.      int64
# Names        object
# Marks       float64
# Hobbies      object
# dtype: object

# %%
df.size
# Out:
# 12

# %% [markdown]
# METHODS OF CLASS DATAFRAME
# 1. df.abs()
# 2. df.add()
# 3. df.aggregate()
# 4. df.assign
# 5. df.count()
# 6. df.describe()
# 7. df.drop() / df.drop_duplicates() / df.duplicated()
# 8. df.head()
# 9. df.info()
# 10. df.insert()
# 11. df.isna()
# 12. df.isnull()
# 13. df.items()
# 14. df.min() / df.max() / df.mean() / df.median()
# 15. df.sort_values() / df.groupby()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Roll_no.  3 non-null      int64
#  1   Names     3 non-null      object
#  2   Marks     3 non-null      float64
#  3   Hobbies   3 non-null      object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 228.0+ bytes

# %%
df.sort_values(by="Marks", ascending=False)
# Out:
#    Roll_no.   Names  Marks  Hobbies
# 2       103   Janvi  90.00  Dancing
# 1       102  Pranay  87.00  Singing
# 0       101  Ayushi  78.27  Reading

# %%
df['Marks'].sum()
# Out:
# np.float64(255.26999999999998)

# %%
df["Marks"].mean()
# Out:
# np.float64(85.08999999999999)

# %%
df.describe()
# Out:
#        Roll_no.      Marks
# count       3.0   3.000000
# mean      102.0  85.090000
# std         1.0   6.093792
# min       101.0  78.270000
# 25%       101.5  82.635000
# 50%       102.0  87.000000
# 75%       102.5  88.500000
# max       103.0  90.000000

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # CREATING A PERSON CLASS
#
# __init__ :- is constructor function used to define attributes

# %%
class Person:
    def __init__(self, name, age, gender, occupation):
        self.name = name
        self.age = age
        self.gender = gender
        self.occupation = occupation
    
    def talk(self):
        print(f"My name is {self.name}")
        print(f"I am {self.age} years old")
        print(f"I am a {self.gender}")
        print(f"I work as a/ an {self.occupation}")

# %%
p1 = Person("Ayushi", 23, "Female", "Data Scientist" )

# %%
p1.talk()
# Out:
# My name is Ayushi
# I am 23 years old
# I am a Female
# I work as a/ an Data Scientist

# %%
print(type(p1))
# Out:
# <class '__main__.Person'>

# %% [markdown]
# __main__ reffers to current working file in python

# %%
p1.name
# Out:
# 'Ayushi'

# %%
p1.age
# Out:
# 23

# %%
p1.gender
# Out:
# 'Female'

# %%
p1.occupation
# Out:
# 'Data Scientist'

# %%
p2 = Person(name = "Pradutt", age= 18, gender= "Male", occupation="Student")

# %%
p2.talk()
# Out:
# My name is Pradutt
# I am 18 years old
# I am a Male
# I work as a/ an Student

# %%
# changing the data 
p2.age = 21

# %%
p2.age
# Out:
# 21

# %%
p2.name = "Pranay"

# %%
p2.name
# Out:
# 'Pranay'

# %% [markdown]
# CREATING A CLASS USING DATACLASSES

# %%
from dataclasses import dataclass

# %%
from typing import Literal

# %%
@dataclass
class student:
    roll_no: int
    name : str
    marks : int| float
    gender : Literal["Male", "Female"]
    hobbies : list[str]

    def get_info(self):
        print(f"Student roll number is {self.roll_no}")
        print(f"Student name is {self.name}")
        print(f"Marks : {self.marks}")
        print(f"Gender of student {self.gender}")
        print(f"Hobbies of student are {self.hobbies}")

# %%
s1 = student(
    roll_no = 23,
    name = "Ayushi",
    marks = 89,
    gender = "Female",
    hobbies = ["Playing", "Yoga"]
)

# %%
s1
# Out:
# student(roll_no=23, name='Ayushi', marks=89, gender='Female', hobbies=['Playing', 'Yoga'])

# %%
s1.roll_no
# Out:
# 23

# %%
s1.name
# Out:
# 'Ayushi'

# %%
s1.marks
# Out:
# 89

# %%
s1.gender
# Out:
# 'Female'

# %%
s1.hobbies
# Out:
# ['Playing', 'Yoga']

# %%
s1.get_info()
# Out:
# Student roll number is 23
# Student name is Ayushi
# Marks : 89
# Gender of student Female
# Hobbies of student are ['Playing', 'Yoga']

# %%
s2 = student(
    roll_no = 2,
    name = "Pradutt",
    marks= 75, 
    gender= "Male",
    hobbies=["Playing football", "Travel around world"]

)

# %%
s2
# Out:
# student(roll_no=2, name='Pradutt', marks=75, gender='Male', hobbies=['Playing football', 'Travel around world'])

# %%
s2.get_info()
# Out:
# Student roll number is 2
# Student name is Pradutt
# Marks : 75
# Gender of student Male
# Hobbies of student are ['Playing football', 'Travel around world']

# %%
s2.marks = 85

# %%
s2.get_info()
# Out:
# Student roll number is 2
# Student name is Pradutt
# Marks : 85
# Gender of student Male
# Hobbies of student are ['Playing football', 'Travel around world']

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
@dataclass
class Account:
    ac_no : int
    name : str
    bal : int| float
    
    def check_balance(self):
        print(f"Current balance in account {self.ac_no} is {self.bal:.2f} INR")

    def depsoite(self, amt: int|float):
        self.bal = self.bal + amt
        print(f"Amount of {amt} INR is Deposited in {self.ac_no}")
        print(f"Available balance in {self.ac_no} is {self.bal}")
    
    def withdraw(self, amt: int | float):
        if self.bal < amt :
            raise ValueError("INSUFFICIENT BALANCE")
        else:
            self.bal = self.bal - amt
            print(f"Amount of {amt} INR is WITHDRAWED from {self.ac_no}")
            print(f"Available balance in {self.ac_no} is {self.bal}")

    def transfer(self, amt : int|float, ac: "Account"):
        self.withdraw(amt)
        ac.depsoite(amt)

# %%
a1 = Account(1001, "Ayushi", 654.27)

# %%
a1.ac_no
# Out:
# 1001

# %%
a1.name
# Out:
# 'Ayushi'

# %%
a1.bal
# Out:
# 654.27

# %%
a1.check_balance()
# Out:
# Current balance in account 1001 is 654.27 INR

# %% [markdown]
# DEPOSITE

# %%
a1.depsoite(500)
# Out:
# Amount of 500 INR is Deposited in 1001
# Available balance in 1001 is 1604.27

# %%
a1.bal
# Out:
# 1154.27

# %% [markdown]
#  WITHDRAW

# %%
a1.withdraw(1000)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 a1.withdraw(1000)
#
# Cell In[12], line 17, in Account.withdraw(self, amt)
#      15 def withdraw(self, amt: int | float):
#      16     if self.bal < amt :
# ---> 17         raise ValueError("INSUFFICIENT BALANCE")
#      18     else:
#      19         self.bal = self.bal - amt
#
# ValueError: INSUFFICIENT BALANCE

# %%
a1.withdraw(50)
# Out:
# Amount of 50 INR is WITHDRAWED from 1001
# Available balance in 1001 is 1104.27

# %% [markdown]
# TRANSFER

# %%
A2 = Account(ac_no= 6789, name="Pranay", bal= 3000)

# %%
A2
# Out:
# Account(ac_no=6789, name='Pranay', bal=3000)

# %%
type(A2)
# Out:
# __main__.Account

# %%
a1.check_balance()
# Out:
# Current balance in account 1001 is 654.27 INR

# %%
A2.check_balance()
# Out:
# Current balance in account 6789 is 3000.00 INR

# %%
a1.transfer(450, A2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 a1.transfer(450, A2)
#
# TypeError: Account.transfer() takes 2 positional arguments but 3 were given
